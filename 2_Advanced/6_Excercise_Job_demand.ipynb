# %% [markdown]
# # Exercise - Analyzing Data Science Job Demand

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_Ind = df[df['job_country'] == 'India'].copy()

# %%
df_Ind
# Out:
#              job_title_short  ...                                    job_type_skills
# 16             Data Engineer  ...  {'cloud': ['databricks', 'azure'], 'databases'...
# 19            Data Scientist  ...  {'analyst_tools': ['tableau'], 'libraries': ['...
# 29            Data Scientist  ...                                               None
# 38              Data Analyst  ...  {'analyst_tools': ['power bi', 'excel', 'word'...
# 42      Senior Data Engineer  ...  {'async': ['jira'], 'cloud': ['aws'], 'librari...
# ...                      ...  ...                                                ...
# 785712         Data Engineer  ...    {'analyst_tools': ['excel'], 'other': ['flow']}
# 785715          Data Analyst  ...                                               None
# 785716     Software Engineer  ...                     {'programming': ['c#', 'sql']}
# 785718      Business Analyst  ...                                               None
# ...

# %%
df_Ind['job_posted_month'] = df_Ind['job_posted_date'].dt.strftime('%B') # using dt extractor to change the format into Months - using str format time function and %B as it is a directive.

# %%
df_Ind
# Out:
#              job_title_short  ... job_posted_month
# 16             Data Engineer  ...             June
# 19            Data Scientist  ...            April
# 29            Data Scientist  ...            March
# 38              Data Analyst  ...             July
# 42      Senior Data Engineer  ...         November
# ...                      ...  ...              ...
# 785712         Data Engineer  ...            March
# 785715          Data Analyst  ...            March
# 785716     Software Engineer  ...            March
# 785718      Business Analyst  ...            March
# 785740     Software Engineer  ...            March
#
# [51088 rows x 18 columns]

# %%
# Now we need to pivot our data necessary to plot it.

df_Ind.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')
# Out:
# job_title_short   Business Analyst  ...  Software Engineer
# job_posted_month                    ...
# April                          170  ...                169
# August                         189  ...                148
# December                       186  ...                133
# February                       143  ...                157
# January                        175  ...                192
# July                           142  ...                155
# June                           146  ...                125
# March                          116  ...                180
# May                            103  ...                 98
# November                       192  ...                139
# October                        170  ...                167
# September                      155  ...                132
#
# [12 rows x 10 columns]

# %%
# as far as we know we can sort it ascending or descending there is no option to sort it chronologically.
# we need to a new column to sort months.

df_Ind_pivot = df_Ind.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')

# %%
df_Ind_pivot.reset_index()
# Out:
# job_title_short job_posted_month  ...  Software Engineer
# 0                          April  ...                169
# 1                         August  ...                148
# 2                       December  ...                133
# 3                       February  ...                157
# 4                        January  ...                192
# 5                           July  ...                155
# 6                           June  ...                125
# 7                          March  ...                180
# 8                            May  ...                 98
# 9                       November  ...                139
# 10                       October  ...                167
# 11                     September  ...                132
#
# [12 rows x 11 columns]

# %%
# it will assume it as 1900 since we haven't defined the year previously.

df_Ind_pivot.reset_index(inplace=True)
df_Ind_pivot['month_no'] = pd.to_datetime(df_Ind_pivot['job_posted_month'], format='%B').dt.month # using an excessor we get only the values for month.

df_Ind_pivot['month_no']
# Out:
# 0      4
# 1      8
# 2     12
# 3      2
# 4      1
# 5      7
# 6      6
# 7      3
# 8      5
# 9     11
# 10    10
# 11     9
# Name: month_no, dtype: int32

# %%
df_Ind_pivot.sort_values('month_no', inplace=True)

# %%
df_Ind_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  ...  Software Engineer  month_no
# 4                        January               175  ...                192         1
# 3                       February               143  ...                157         2
# 7                          March               116  ...                180         3
# 0                          April               170  ...                169         4
# 8                            May               103  ...                 98         5
# 6                           June               146  ...                125         6
# 5                           July               142  ...                155         7
# 1                         August               189  ...                148         8
# 11                     September               155  ...                132         9
# 10                       October               170  ...                167        10
# ...

# %%
df_Ind_pivot.set_index('job_posted_month', inplace=True)
df_Ind_pivot.drop(columns='month_no', inplace=True)

# %%
df_Ind_pivot
# Out:
# job_title_short   Business Analyst  ...  Software Engineer
# job_posted_month                    ...
# January                        175  ...                192
# February                       143  ...                157
# March                          116  ...                180
# April                          170  ...                169
# May                            103  ...                 98
# June                           146  ...                125
# July                           142  ...                155
# August                         189  ...                148
# September                      155  ...                132
# October                        170  ...                167
# November                       192  ...                139
# December                       186  ...                133
#
# [12 rows x 10 columns]

# %%
df_Ind_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
# Since the above graph is so cluttered lets make a plot with the top 3 jobs in demand.

top_3 = df_Ind['job_title_short'].value_counts().head(3)  # specifying  we require only the top three based on counts.

top_3
# Out:
# job_title_short
# Data Engineer     19062
# Data Scientist    13279
# Data Analyst       6121
# Name: count, dtype: int64

# %%
top_3.index # to only get the names.
# Out:
# Index(['Data Engineer', 'Data Scientist', 'Data Analyst'], dtype='object', name='job_title_short')

# %%
top_3 = top_3.index.tolist() # convert to a list to get the cols names only

# %%
df_Ind_pivot[top_3].plot(kind='line')
plt.ylabel('Job Count')
plt.xlabel('2023')
plt.title('Monthly Job Postings for Top Data Jobs in India')
# Out:
# Text(0.5, 1.0, 'Monthly Job Postings for Top Data Jobs in India')
